# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class SpecSpider(scrapy.Spider):
    name = 'Spec'
    
    start_urls = [
        'https://www.spectator.co.uk/?nogeoredir=1',
    ]
    
    def parse(self, response):
        
        for div in response.xpath('//div'):
            
            output = list(div.xpath('div[contains(@class, "card")]/div/h2/a/text()').extract())
            if output: 
                for i in output:
                    yield {
                        'title': i
                    }

            
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'specfrontpage.json',
    'LOG_ENABLED': False
})

process.crawl(SpecSpider)
process.start()
print('Done')
# Out:
# Done

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class SpecSpider(scrapy.Spider):
    name = 'Spec'
    
    start_urls = [
        'https://www.spectator.co.uk/?nogeoredir=1',
    ]
    
    def parse(self, response):
        
        for div in response.xpath('//div[contains(@class, "card__text")]'):
            
            yield {
                'title': div.xpath('h2/a[@class="card__title-link"]/text()').extract(),
                'author': div.xpath('div/div[contains(@class, "meta__author")]/a/text()').extract()
            }
            
            
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'specfrontpage.json',
    'LOG_ENABLED': False
})

process.crawl(SpecSpider)
process.start()
print('Done')
# Out:
# Done

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class SpecSpider(scrapy.Spider):
    name = 'Spec'
    
    start_urls = [
        'https://www.spectator.co.uk/?nogeoredir=1',
    ]
    
    def parse(self, response):
        
        for div in response.xpath('//div[contains(@class, "card__text")]'):
            
            title1 = list(div.xpath('h2/a[@class="card__title-link"]/text()').extract())
            title2 = list(div.xpath('h3/a[@class="card__title-link"]/text()').extract())
            
            title = title1
            if not title:
                title = title2
            
            author1 = list(div.xpath('div/div[contains(@class, "meta__author")]/a/text()').extract())
            author2 = list(div.xpath('div[contains(@class, "meta__author")]/a/text()').extract())
            author3 = list(div.xpath('div/div[contains(@class, "meta__author")]/div/a/text()').extract())
            
            author = author1
            if not author:
                author = author2
            if not author:
                author = author3
            if not author:
                continue
                
            yield {
                'title': title,
                'author': author
            }
            
            
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'specfrontpage.json',
    'LOG_ENABLED': False
})

process.crawl(SpecSpider)
process.start()
print('Done')
# Out:
# Done

# %%
import pandas as pd
spec = pd.read_json('specfrontpage.json')
spec
# Out:
#                 author                                              title
# 0     [Douglas Murray]   [The confusing modern rules of telling a ‘joke’]
# 1          [Paul Wood]                [The brutality of the Isis Beatles]
# 2      [Robert Peston]  [Why Tory members don’t care about the Carrie ...
# 3     [Robert Jackman]                 [London’s best animal experiences]
# 4      [Fiona Sampson]  [Hugo Williams’ haunting and hallucinatory hos...
# 5      [Laurie Graham]     [What I’ve learned from 20 years without a TV]
# 6   [Melanie McDonagh]               [Boris has to get out of Camberwell]
# 7        [Ivan Rogers]  [Ivan Rogers: no deal is now the most likely B...
# 8       [James Kirkup]     [This tape will always threaten Boris Johnson]
# 9         [Ross Clark]  [There’s no denying the Boris tape was politic...
# 10     [Robert Peston]  [Why Tory members don’t care about the Carrie ...
# 11   [Brendan O'Neill]  [The moral arrogance of the Mansion House clim...
# ...

# %%
spec.loc[1, 'title']
# Out:
# 'John Bercow’s authority has now collapsed'

# %%
x = []

# %%
if not x:
    print('Yes')
# Out:
# Yes
